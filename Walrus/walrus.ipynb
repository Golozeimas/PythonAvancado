# %%
numeros_em_lista = [12, 23, 1, 3, 4, 5, 30, 40]

# %%
# Filtrar e armazenar números maiores que 10

numeros_maiores_que_10 = [n for n in numeros_em_lista if (maior := n) > 10]
numeros_maiores_que_10
# Out:
# [12, 23, 30, 40]

# %%
linhas_processadas = []
with open("arquivo.txt","r",encoding="utf-8") as arquivo:
    for linha in arquivo:
        if (linha_limpa := linha.strip()):
            linhas_processadas.append(linha_limpa)

# %%
linhas_processadas
# Out:
# ['Python é legal', 'Java é GOD', 'Ser dev é pancada', 'O Brasil tá foda']

# %%
while (nome := input("Digite algo:")) != "sair":
    print(nome)

# entendi basicamente pega o valor de uma função e a utlizar e ao mesmo tempo guarda ela
# Out:
# oi
# mitada
